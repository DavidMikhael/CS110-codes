# %% [raw]
#                                                      CS110
#
#                                                    Assigment2
#
#                                                    Fall 2021

# %%
table = [('description', 'availability', 'task_id', 'duration', 'dependencies', 'status'),
('Doing Church Service', 1, 1, 120, [13,14], 'N'),
('Sign up for church service', 1, 13, 5, [], 'N'), 
('Prepare gifts for kids', 1, 14, 15, [], 'N'),        
('Playing Violin', 6, 2, 30, [10,11,12], 'N'),
('Studying music theory', 6, 11, 10, [], 'N'),
('Tune the violin strings', 6, 12, 5, [], 'N'),
("Listen to Friend's recent musical piece", 6, 10, 30, [], 'N'),
('Doing Yoga', 2, 3, 60, [15,16], 'N'),
('Text my Yoga buddy to arrange going for Yoga', 2, 15, 2, [], 'N'),
('Clean the Yoga mat', 2, 16, 5, [], 'N'),
('Going out with friends', 4, 4, 60, [17,18], 'N'),
('Text my friends to arrange going out', 4, 17, 5, [], 'N'),
('Search on Maps for new places to visit', 4, 18, 5, [], 'N'),
('Working out in the Gym', 5, 5, 45, [6,19], 'N'),
('Make healthy food',5, 6, 120, [], 'N'),
('Take a fitness lesson by my trainer', 5, 19, 20, [], 'N'),
('English Tutoring in a Non-Profit', 1, 7, 120, [20,21], 'N'),
('Preparing lesson plans', 1, 20, 20, [], 'N'),
('Sign up for tutoring', 1, 21, 5, [], 'N'),
('Study and do work (at SF Library)', 3, 8, 180, [], 'N'),
('Call Family', 4, 9, 60, [], 'N'), 
]
        
    
import pandas as pd

df = pd.DataFrame(table)
df.to_csv('file2.csv', index = False, header=False)
pd.read_csv("file2.csv")
# Out:
#                                      description  availability  task_id  \
# 0                           Doing Church Service             1        1
# 1                     Sign up for church service             1       13
# 2                         Prepare gifts for kids             1       14
# 3                                 Playing Violin             6        2
# 4                          Studying music theory             6       11
# 5                        Tune the violin strings             6       12
# 6        Listen to Friend's recent musical piece             6       10
# 7                                     Doing Yoga             2        3
# 8   Text my Yoga buddy to arrange going for Yoga             2       15
# 9                             Clean the Yoga mat             2       16
# 10                        Going out with friends             4        4
# 11          Text my friends to arrange going out             4       17
# 12        Search on Maps for new places to visit             4       18
# 13                        Working out in the Gym             5        5
# 14                             Make healthy food             5        6
# 15           Take a fitness lesson by my trainer             5       19
# 16              English Tutoring in a Non-Profit             1        7
# 17                        Preparing lesson plans             1       20
# 18                          Sign up for tutoring             1       21
# 19             Study and do work (at SF Library)             3        8
# 20                                   Call Family             4        9
#
#     duration  dependencies status
# 0        120      [13, 14]      N
# 1          5            []      N
# 2         15            []      N
# 3         30  [10, 11, 12]      N
# 4         10            []      N
# 5          5            []      N
# 6         30            []      N
# 7         60      [15, 16]      N
# 8          2            []      N
# 9          5            []      N
# 10        60      [17, 18]      N
# 11         5            []      N
# 12         5            []      N
# 13        45       [6, 19]      N
# 14       120            []      N
# 15        20            []      N
# 16       120      [20, 21]      N
# 17        20            []      N
# 18         5            []      N
# 19       180            []      N
# 20        60            []      N

# %% [raw]
# The tasks I include are essential to my daily life; they are not all executed everyday, but these are essentially what fill my time during the semester apart from academics. Yoga and Gym are essential for my physical and mental health. Violin and listening to my friend's compositions help improve my mood and add energy. The church kids serive and English tutoring are two activities that allow me to interact with different people in the city of SF and get outside my comfort zone while helping others. Calling family is essential for my mental wellbeing and for theirs too, and studying at SF public library is more productive that anywhere else with books that help me know more about the culture and history of SF. Finally, I need to do make healthy food whenever I want to go to the gym to save money and build muscles. Some tasks need to be done before others (have sub tasks). Tasks and their subtasks have the same priority level.
#
# I store these tasks in a list of tuples because I find it easier to deal with and since I don't need a mutable data type; my input tasks are always the same. In the table, each row represents a task, and each column represents a property of that task. Each task had an id from 1 to 9, a duration in minutes and a list of task(s) it is dependent on. Each task also has a status that is "not started" by default but gets updated during the code. Finally, each task also has an "availability" value which is basically how many days of the week this task could be done on. This is my priority value, where a task that could be done on only a few number of days has a higher priority of being completed on time than another one that could be done at any time. Sunday is a day when all these tasks could be done, so I assume that these are Sunday's tasks; For example, Church service and English tutoring could only be done on Sundays and thus they are prioritized than other tasks that could still be done on other days.
#
# My scheduler works by first checking if there still tasks that are not completed yet or in the priority queue. If yes, it takes tasks that are not started yet, and those that don't have dependencies, and use the "heappush" function to insert them into a priority queue. The heappush function inserts those executable tasks to the priority queue in an ascending order of their priority which is the "availability" value. Then, the scheduler extracts the first task in the priority queue (the one with highest priority), execute it with recorded time, change its status to completed, and remove it from any dependency list so that tasks that are dependent on it can be executed. After the task is extracted using "heappop", "heapify" resorts the priority queue. After we finish our first iteration, we check tasks again to push to the queue those who weren't included before because they had dependencies that are now executed. This gives us an appropriate priority queue that we, again, extract the first element of and execute it, and so on until we finish all tasks (that is, until the length of the priority queue is 0 and all tasks are COMPLETED.
#
# A minimum priority queue is a suitable data structure for sorting tasks because it ensures that the heap sorting property is maintained at each iteration, where each task we extract at each time is the root parent node and thus it is the one with the highest priority (the least availability value). So, we can execute tasks based on priorities we assign to each. Moreever, the priority queue consider dependencies because only elements whose dependencies has been executed enter the priority queue. Therefore, as seen in the output, the scheduler considers both priorities and dependencies.
#
# The example output I have is excellent because each task, along with its subtasks, is executed one after another based on its priority, that is common over all subtasks, given the dependency constraints.

# %%
class Task:
    """
    - id: Task Id   
    - description: Short description of the task   
    - duration: Duration in minutes   
    - priority: Priority level of a task (ranging from 0 to 100)   
    - status: Current status of the task:       
   
    """
    #Initializes an instance of Task
    def __init__(self, availability,description, task_id,duration,dependencies, status="N"):
        self.availability=availability
        self.id= task_id
        self.description=description
        self.duration=duration
        self.dependencies=dependencies
        self.status=status
        
        
        
    def __repr__(self):
        return f"availability: {self.availability}\n {self.description}\n -  id: {self.id}\n \
        \tDuration:{self.duration}\n\tDepends on: {self.dependencies}\n\tStatus:{self.status}"

    #Determines what element in the priority queue is to be compared whenever < is used
    def __lt__(self, other):
        return self.availability < other.availability 


class TaskScheduler:
    """
    A Simple Daily Task Scheduler Using Priority Queues
    """
    
    #Initializing symbols for possible task status
    NOT_STARTED ='N'
    IN_PRIORITY_QUEUE = 'I'  
    COMPLETED = 'C'
    
    def __init__(self, tasks):
        self.tasks = tasks
        self.priority_queue = [] 
        
    def print_self(self):
        print('Input List of Tasks')
        for t in self.tasks:
            print(t) 
    
    #Initializing parent, right, and left nodes
    def parent(self, i):
        return (i - 1)//2

    def right(self, i):
        return 2 * i + 2

    def left(self, i):
        return 2 * i + 1
    
    
    def mink(self):      
        """ 
        Returns the smallest key in the priority queue.  
         
        Parameters 
        ---------- 
        None 
 
        Returns 
        ---------- 
        int 
            the smallest key in the priority queue 
 
        """ 
        return self.priority_queue[0]      
     
   
    def heappush_min(self, key):   
        """ 
        Insert a key into a priority queue  
         
        Parameters 
        ---------- 
        key: int 
            The key value to be inserted 
 
        Returns 
        ---------- 
        None 
        """  
        #Inserts the new key to the end of the queue
        self.priority_queue.append(key) 
        
        #Maintains heap property by correctly inserting that new key
        self.add_key(0,len(self.priority_queue)-1) 
        
    def add_key(self,start,end):
        """
        Puts the key in the priority queue in the appropriate position based on its
        priority value compared to the supposed parent node
        
        Parameters
        ----------
        start: int
            The beginning of the queue
        end: int
            The index of the new key value (the last queue element)

        Returns
        ----------
        None
        """
        
        new_item = self.priority_queue[end]
        while end > start:
            #Creates a parent element that is then compared to the added key
            parent = self.parent(end)
            parent_element = self.priority_queue[parent]
            #Since this is min heap, if the new key is less than the parent, they swap
            #and the parent index updates
            if new_item < parent_element:
                self.priority_queue[end] = parent_element
                end = parent
                continue
            break
        self.priority_queue[end]=new_item

             
        
    def min_heapify(self,pos):
        """
        Creates a min heap from the index given
        
        Parameters
        ----------
        pos: int
            The index of of the root parent node of the subtree to be heapified

        Output
        ----------
        A queue with renewed heap property
        """
        l = self.left(pos)
        r = self.right(pos)
        priority_queue = self.priority_queue
        smallest = pos
        
        #Look for the smallest element among parent (initially the smallest), left,
        #and right
        if l < len(priority_queue) and priority_queue[smallest] > priority_queue[l]:
            smallest = l
        if r < len(priority_queue) and priority_queue[smallest] > priority_queue[r]:
            smallest = r
            
        #If the parent is not actually the smallest, swap it with the smallest and
        #maintain heap property
        if smallest != pos: 
            priority_queue[smallest], priority_queue[pos] = \
            priority_queue[pos], priority_queue[smallest]
            self.min_heapify(smallest)
             
    def heappop(self):
        """
        returns the smallest key in the min priority queue
        and remove it from the queue
        
        Parameters
        ----------
        None
        
        Returns
        ----------
        int
            the minimum value in the priority queue, which is the first element
            (that we swap with the last element to pop it easily)
        """
        
        last_item = self.priority_queue.pop()
        
        if self.priority_queue:
            
            #The minimum element is the first element, which is swapped with the last
            #element that is then popped (extracted) before the next iteration
            mink = self.priority_queue[0]
            self.priority_queue[0] = last_item
            
            #Calling heapify to maintain the heap property after we popped the root node
            self.min_heapify(0)
            return mink
        return last_item
                   
            
    def remove_dependency(self, task_id):
        """
        It removes a task from wherever it's found in a list of dependencies once
        it's executed
        
        Parameters
        --------------------
        task_id of the task just completed
        
        Input
        --------------------
        list of tasks
        
        Output
        -----------------------
        lists of tasks with t_id removed
        """
        for t in self.tasks:
            if t.id != task_id and task_id in t.dependencies:
                t.dependencies.remove(task_id)           
            
    def get_tasks_ready(self):
        """ 
        Implements step 1 of the scheduler 
        
        Parameters
        --------------------
        None
        
        Input
        --------------------
        list of tasks
        
        Output
        --------------------
        list of tasks that are ready to execute (i.e. tasks with no pending
        task dependencies)
        
        """
        for task in self.tasks:
            if task.status == self.NOT_STARTED and not task.dependencies: # If task has no
                #dependencies and is not yet in queue
                task.status = self.IN_PRIORITY_QUEUE # Change status of the task
               # Push task into its correct position in the priority queue
                self.heappush_min(task)
                
    
    def check_unscheduled_tasks(self):
        """
        Checks if there is a task that is still not started
        
        Parameters
        -------------------
        None
        
        Input
        -------------------
        list of tasks 
        
        Output
        -------------------
        boolean (checks the status of all tasks and returns True if at least one
        task has status = 'N')
        """
        for task in self.tasks:
            if task.status == self.NOT_STARTED:
                return True
        return False   
    
    def format_time(self, time):
        return f"{time//60}h{time%60:02}"
     
    def run_task_scheduler(self, starting_time = 480):
        """
        Runs the scheduling process for tasks in the order of their priority
        
        Parameters
        -------------------
        starting time of tasks' execution
        
        Output
        -------------------
        A print statement before the task begins with the time of start, and a print
        statement after it ends with the time of finish
        
        
        
        """
        
        current_time = starting_time
        
        #STEPs 1 and 2: Extract tasks ready to execute (those without dependencies)
        #and push them into the priority queue
        while self.check_unscheduled_tasks() or self.priority_queue:
            
            self.get_tasks_ready()
            
            #STEP 3: Check for tasks in the priority queue.  
            if len(self.priority_queue) > 0 :      
                # STEP 4: get the tasks on top of the priority queue
                pop = self.heappop()
                print(f"⏰Simple Scheduler at time {self.format_time(current_time)}\
        started executing task {pop.id} that takes {pop.duration} mins")
                current_time += pop.duration            
                print(f"✅ Completed Task {pop.id} - '{pop.description}' at time\
        {self.format_time(current_time)}\n") 
                ####### if the task is completed, it cannot be a dependency on other tasks,
                #so remove it from the dependency list
                self.remove_dependency(pop.id)
                self.tasks[self.tasks.index(pop)].status = self.COMPLETED
                
        total_time = current_time - starting_time             
        print(f"🏁 Completed all planned tasks in {total_time//60}h{total_time%60:02}min")

# %%
new = [
    Task(1,'Doing Church Service', 1, 120, [13,14], 'N'),
    Task(1,'Sign up for church service', 13, 5, [], 'N'),
    Task(1,'Prepare gifts for kids', 14, 15, [], 'N'),
    Task(6,'Playing Violin', 2, 30, [10,11,12], 'N'),
    Task(6,'Studying music theory', 11, 10, [], 'N'),
    Task(6,'Tune the violin strings', 12, 5, [], 'N'),
    Task(6,"Listen to Friend's recent musical piece", 10, 30, [], 'N'),
    Task(2,'Doing Yoga', 3, 60, [15,16], 'N'),
    Task(2,'Text my Yoga buddy to arrange going for Yoga', 15, 2, [], 'N'),
    Task(2,'Clean the Yoga mat', 16, 5, [], 'N'),
    Task(4,'Going out with friends', 4, 60, [17,18], 'N'),
    Task(4,'Text my friends to arrange going out', 17, 5, [], 'N'),
    Task(4,'Search on Maps for new places to visit', 18, 5, [], 'N'),
    Task(5,'Working out in the Gym', 5, 45, [6,19], 'N'),
    Task(5,'Make healthy food', 6, 120, [], 'N'),
    Task(5,'Take a fitness lesson by my trainer', 19, 20, [], 'N'),
    Task(1,'English Tutoring in a Non-Profit', 7, 120, [20,21], 'N'),
    Task(1,'Preparing lesson plans', 20, 20, [], 'N'),
    Task(1,'Sign up for tutoring', 21, 5, [], 'N'),
    Task(3,'Study and do work (at SF Library)', 8, 180, [], 'N'),
    Task(4,'Call Family', 9, 60, [], 'N'),
]





task_scheduler = TaskScheduler(new)




task_scheduler.run_task_scheduler()
# Out:
# ⏰Simple Scheduler at time 8h00        started executing task 13 that takes 5 mins
# ✅ Completed Task 13 - 'Sign up for church service' at time        8h05
#
# ⏰Simple Scheduler at time 8h05        started executing task 14 that takes 15 mins
# ✅ Completed Task 14 - 'Prepare gifts for kids' at time        8h20
#
# ⏰Simple Scheduler at time 8h20        started executing task 20 that takes 20 mins
# ✅ Completed Task 20 - 'Preparing lesson plans' at time        8h40
#
# ⏰Simple Scheduler at time 8h40        started executing task 21 that takes 5 mins
# ✅ Completed Task 21 - 'Sign up for tutoring' at time        8h45
#
# ⏰Simple Scheduler at time 8h45        started executing task 1 that takes 120 mins
# ✅ Completed Task 1 - 'Doing Church Service' at time        10h45
#
# ⏰Simple Scheduler at time 10h45        started executing task 7 that takes 120 mins
# ✅ Completed Task 7 - 'English Tutoring in a Non-Profit' at time        12h45
#
# ⏰Simple Scheduler at time 12h45        started executing task 15 that takes 2 mins
# ✅ Completed Task 15 - 'Text my Yoga buddy to arrange going for Yoga' at time        12h47
#
# ⏰Simple Scheduler at time 12h47        started executing task 16 that takes 5 mins
# ✅ Completed Task 16 - 'Clean the Yoga mat' at time        12h52
#
# ⏰Simple Scheduler at time 12h52        started executing task 3 that takes 60 mins
# ✅ Completed Task 3 - 'Doing Yoga' at time        13h52
#
# ⏰Simple Scheduler at time 13h52        started executing task 8 that takes 180 mins
# ✅ Completed Task 8 - 'Study and do work (at SF Library)' at time        16h52
#
# ⏰Simple Scheduler at time 16h52        started executing task 17 that takes 5 mins
# ✅ Completed Task 17 - 'Text my friends to arrange going out' at time        16h57
#
# ⏰Simple Scheduler at time 16h57        started executing task 18 that takes 5 mins
# ✅ Completed Task 18 - 'Search on Maps for new places to visit' at time        17h02
#
# ⏰Simple Scheduler at time 17h02        started executing task 9 that takes 60 mins
# ✅ Completed Task 9 - 'Call Family' at time        18h02
#
# ⏰Simple Scheduler at time 18h02        started executing task 4 that takes 60 mins
# ✅ Completed Task 4 - 'Going out with friends' at time        19h02
#
# ⏰Simple Scheduler at time 19h02        started executing task 6 that takes 120 mins
# ✅ Completed Task 6 - 'Make healthy food' at time        21h02
#
# ⏰Simple Scheduler at time 21h02        started executing task 19 that takes 20 mins
# ✅ Completed Task 19 - 'Take a fitness lesson by my trainer' at time        21h22
#
# ⏰Simple Scheduler at time 21h22        started executing task 5 that takes 45 mins
# ✅ Completed Task 5 - 'Working out in the Gym' at time        22h07
#
# ⏰Simple Scheduler at time 22h07        started executing task 10 that takes 30 mins
# ✅ Completed Task 10 - 'Listen to Friend's recent musical piece' at time        22h37
#
# ⏰Simple Scheduler at time 22h37        started executing task 12 that takes 5 mins
# ✅ Completed Task 12 - 'Tune the violin strings' at time        22h42
#
# ⏰Simple Scheduler at time 22h42        started executing task 11 that takes 10 mins
# ✅ Completed Task 11 - 'Studying music theory' at time        22h52
#
# ⏰Simple Scheduler at time 22h52        started executing task 2 that takes 30 mins
# ✅ Completed Task 2 - 'Playing Violin' at time        23h22
#
# 🏁 Completed all planned tasks in 15h22min

# %% [raw]
# Each task also has a multitasking metric, which is cogntivei demand, from 0 to 1, with values near one meaning a very demanding task that is not likely to be multitasked, and values near zero meaning a task that could be done with other tasks, condition on the sum of the two values being not more than one. For example, Studying music theory (demand = 0.6) can be done with listening to my Friend's recent musical piece (demand = 0.4) but not with preparing gifts for kids (demand = 0.5).
#
# In the time counter, I made sure that a task starts only after the "longest" one of the two tasks that are multitasked is executed. I also made sure that the counter includes the time of beginning each of the multitasksed tasks (which is the same) and the time of finishing each separately (if their duration is different). Finally, I thought why we, after finishing the main task of the multitasked pair, would still spend more time in the secondary task if it takes longer. But since it's secondary and not cognitively demanding, I decided that this is better than allocating a whole different time slot for it (e.g. listening to my friend's music piece).
#
# Finally, I made sure that no more than two tasks can be done at the same time. I set my multitasking limit to be 2, since I am not efficient in doing more than 2 tasks at the same time whatever these tasks are. Also, I made the code search for potenial tasks to be multitasked in only the first 3 elements of the priority queue, which are most likely to be subtasks of the same task.
#
# The outcome of this algorithm is also excellent because non-demanding subtasks of the same task are efficiently executed together followed by their main task (that is dependent on them), and this process happens for one main task after another based on the priority values.
#
# Note that when I use multitasking, there should some minor changes in the order of some tasks but which do not impact my overall schedule goals and expectations. For example, I can do church service after I finish all tasks that concern service and tutoring, or after I only finish church service tasks. Both ways are equally efficient to me and I might alternate between them.

# %%
class Task:
    """
    - id: Task Id   
    - description: Short description of the task   
    - duration: Duration in minutes   
    - priority: Priority level of a task (ranging from 0 to 100)   
    - status: Current status of the task:       
   
    """
    #Initializes an instance of Task
    def __init__(self, availability,description, task_id,duration,dependencies, \
                 multitasking, status="N"):
        self.availability=availability
        self.id= task_id
        self.description=description
        self.duration=duration
        self.dependencies=dependencies
        self.multitasking=multitasking
        self.status=status
    
        
    def __repr__(self):
        return f"availability: {self.availability}\n {self.description}\n -  id: {self.id} \
        \n \tDuration:{self.duration}\n\tDepends on: {self.dependencies}\n\tStatus: \
        {self.status} \n \tMultitasking: {self.multitasking}"

    #Determines what element in the priority queue is to be compared whenever < is used
    def __lt__(self, other):
        return self.availability < other.availability 

    
pop = []
    
class TaskScheduler:
    """
    A Simple Daily Task Scheduler Using Priority Queues
    """
    
    #Initializing symbols for possible task status
    NOT_STARTED ='N'
    IN_PRIORITY_QUEUE = 'I'  
    COMPLETED = 'C'
    
    def __init__(self, tasks):
        self.tasks = tasks
        self.priority_queue = [] 
        
    def print_self(self):
        print('Input List of Tasks')
        for t in self.tasks:
            print(t) 
    
    #Initializing parent, right, and left nodes
    def parent(self, i):
        return (i - 1)//2

    def right(self, i):
        return 2 * i + 2

    def left(self, i):
        return 2 * i + 1
    
    
    def mink(self):      
        """ 
        Returns the smallest key in the priority queue.  
         
        Parameters 
        ---------- 
        None 
 
        Returns 
        ---------- 
        int 
            the smallest key in the priority queue 
 
        """ 
        return self.priority_queue[0]      
     
   
    def heappush_min(self, key):   
        """ 
        Insert a key into a priority queue  
         
        Parameters 
        ---------- 
        key: int 
            The key value to be inserted 
 
        Returns 
        ---------- 
        None 
        """  
        #Inserts the new key to the end of the queue
        self.priority_queue.append(key) 
        
        #Maintains heap property by correctly inserting that new key
        self.add_key(0,len(self.priority_queue)-1) 
        
    def add_key(self,start,end):
        """
        Puts the key in the priority queue in the appropriate position based on its
        priority value compared to the supposed parent node
        
        Parameters
        ----------
        start: int
            The beginning of the queue
        end: int
            The index of the new key value (the last queue element)

        Returns
        ----------
        None
        """
        
        new_item = self.priority_queue[end]
        while end > start:
            #Creates a parent element that is then compared to the added key
            parent = self.parent(end)
            parent_element = self.priority_queue[parent]
            #Since this is min heap, if the new key is less than the parent,
            #they swap and the parent index updates
            if new_item < parent_element:
                self.priority_queue[end] = parent_element
                end = parent
                continue
            break
        self.priority_queue[end]=new_item

             
        
    def min_heapify(self,pos):
        """
        Creates a min heap from the index given
        
        Parameters
        ----------
        pos: int
            The index of of the root parent node of the subtree to be heapified

        Output
        ----------
        A queue with renewed heap property
        """
        l = self.left(pos)
        r = self.right(pos)
        priority_queue = self.priority_queue
        smallest = pos
        
        #Look for the smallest element among parent (initially the smallest), left,
        #and right
        if l < len(priority_queue) and priority_queue[smallest] > priority_queue[l]:
            smallest = l
        if r < len(priority_queue) and priority_queue[smallest] > priority_queue[r]:
            smallest = r
            
        #If the parent is not actually the smallest, swap it with the smallest and
        #maintain heap property
        if smallest != pos: 
            priority_queue[smallest], priority_queue[pos] = \
            priority_queue[pos], priority_queue[smallest]
            self.min_heapify(smallest)
             
    def heappop(self):
        """
        returns the smallest key in the min priority queue
        and remove it from the queue
        
        Parameters
        ----------
        None
        
        Returns
        ----------
        int
            the minimum value in the priority queue, which is the first element
            (that we swap with the last element to pop it easily)
        """
        
        last_item = self.priority_queue.pop()
        
        if self.priority_queue:
            
            #The minimum element is the first element, which is swapped with the
            #last element that is then popped (extracted) before the next iteration
            mink = self.priority_queue[0]
            self.priority_queue[0] = last_item
            
            #Calling heapify to maintain the heap property after we popped the root node
            self.min_heapify(0)
            return mink
        return last_item
                   
            
    def remove_dependency(self, task_id):
        """
        It removes a task from wherever it's found in a list of dependencies once
        it's executed
        
        Parameters
        --------------------
        task_id of the task just completed
        
        Input
        --------------------
        list of tasks
        
        Output
        -----------------------
        lists of tasks with t_id removed
        """
        for t in self.tasks:
            if t.id != task_id and task_id in t.dependencies:
                t.dependencies.remove(task_id)           
            
    def get_tasks_ready(self):
        """ 
        Implements step 1 of the scheduler 
        
        Parameters
        --------------------
        None
        
        Input
        --------------------
        list of tasks
        
        Output
        --------------------
        list of tasks that are ready to execute (i.e. tasks with
        no pendending task dependencies)
        
        """
        for task in self.tasks:
            if task.status == self.NOT_STARTED and not task.dependencies: # If task has no
                #dependencies and is not yet in queue
                task.status = self.IN_PRIORITY_QUEUE # Change status of the task
               # Push task into its correct position in the priority queue
                self.heappush_min(task)
                
    
    def check_unscheduled_tasks(self):
        """
        Checks if there is a task that is still not started
        
        Parameters
        -------------------
        None
        
        Input
        -------------------
        list of tasks 
        
        Output
        -------------------
        boolean (checks the status of all tasks and returns True if at least one
        task has status = 'N')
        """
        for task in self.tasks:
            if task.status == self.NOT_STARTED:
                return True
        return False   
    
    def format_time(self, time):
        return f"{time//60}h{time%60:02}"
     
    def run_task_scheduler(self, starting_time = 480):
        
        current_time = starting_time
        
        #STEPs 1 and 2: Extract tasks ready to execute (those without dependencies)
        #and push them into the priority queue
        while self.check_unscheduled_tasks() or self.priority_queue:
            
            self.get_tasks_ready()

            pop = []
            specific_time = []
            duration = 0
            
            #STEP 3: Check for tasks in the priority queue.
            if len(self.priority_queue) > 0 :        
                # STEP 4: get the tasks on top of the priority queue
                pop.append(self.heappop())
                print(f"⏰Simple Scheduler at time {self.format_time(current_time)}\
            started executing task {pop[0].id} that takes {pop[0].duration} mins")
                
                #Step 5: Multitasking
                if pop[0].multitasking < 1:
                    for element in self.priority_queue[:3]:
                        if element.multitasking + pop[0].multitasking <= 1:
                            pop.append(element)
                            self.priority_queue.remove(element)
                            print(f"⏰Simple Scheduler at time {self.format_time(current_time)}\
            started executing task {element.id} that takes {element.duration} mins")

                            break
                        else:
                            continue
                            
                       
                dur = []
                for i in range(len(pop)):
                    dur.append(pop[i].duration)
                    duration = max(dur)
                    specific_time.append(pop[i].duration)
                
                current_time += duration             
                 
                
                # if the task is completed, it cannot be a dependency on other tasks,
                #so remove it from the dependency list
                for i in range(len(pop)):
                    
                    print(f"✅ Completed Task {pop[i].id} - '{pop[i].description}' at time\
            {self.format_time(current_time - duration + specific_time[i])}\n") 
                    self.remove_dependency(pop[i].id)
                    self.tasks[self.tasks.index(pop[i])].status = self.COMPLETED
            
                
        total_time = current_time - starting_time             
        print(f"🏁 Completed all planned tasks in {total_time//60}h{total_time%60:02}min")

# %%
new = [
    Task(1,'Doing Church Service', 1, 120, [13,14], 1, 'N'),
    Task(1,'Sign up for church service', 13, 5, [], 0.5, 'N'),
    Task(1,'Prepare gifts for kids', 14, 15, [], 0.5, 'N'),
    Task(6,'Playing Violin', 2, 30, [10,11,12], 1, 'N'),
    Task(6,'Studying music theory', 11, 10, [], 0.6, 'N'),
    Task(6,'Tune the violin strings', 12, 5, [], 1, 'N'),
    Task(6,"Listen to my Friend's recent musical piece", 10, 30, [], 0.4, 'N'),
    Task(2,'Doing Yoga', 3, 60, [15,16], 1, 'N'),
    Task(2,'Text my Yoga buddy to arrange going for Yoga', 15, 2, [], 0.3, 'N'),
    Task(2,'Clean the Yoga mat', 16, 5, [], 0.7, 'N'),
    Task(5,'Going out with friends', 4, 60, [17,18], 1, 'N'),
    Task(5,'Text my friends to arrange going out', 17, 5, [], 0.3, 'N'),
    Task(5,'Search on Maps for new places to visit', 18, 5, [], 0.3, 'N'),
    Task(4,'Working out in the Gym', 5, 45, [6,19], 1, 'N'),
    Task(4,'Make healthy food', 6, 120, [], 1, 'N'),
    Task(4,'Take a fitness lesson by my trainer', 19, 20, [], 1, 'N'),
    Task(1,'English Tutoring in a Non-Profit', 7, 120, [20,21], 1, 'N'),
    Task(1,'Prepare lesson plans', 20, 20, [], 0.5, 'N'),
    Task(1,'Sign up for tutoring', 21, 5, [], 0.5, 'N'),
    Task(3,'Study and do work (at SF Library)', 8, 180, [], 1, 'N'),
    Task(4,'Call Family', 9, 60, [], 1, 'N'),
]





task_scheduler = TaskScheduler(new)




task_scheduler.run_task_scheduler()
# Out:
# ⏰Simple Scheduler at time 8h00            started executing task 13 that takes 5 mins
# ⏰Simple Scheduler at time 8h00            started executing task 14 that takes 15 mins
# ✅ Completed Task 13 - 'Sign up for church service' at time            8h05
#
# ✅ Completed Task 14 - 'Prepare gifts for kids' at time            8h15
#
# ⏰Simple Scheduler at time 8h15            started executing task 1 that takes 120 mins
# ✅ Completed Task 1 - 'Doing Church Service' at time            10h15
#
# ⏰Simple Scheduler at time 10h15            started executing task 20 that takes 20 mins
# ⏰Simple Scheduler at time 10h15            started executing task 21 that takes 5 mins
# ✅ Completed Task 20 - 'Prepare lesson plans' at time            10h35
#
# ✅ Completed Task 21 - 'Sign up for tutoring' at time            10h20
#
# ⏰Simple Scheduler at time 10h35            started executing task 7 that takes 120 mins
# ✅ Completed Task 7 - 'English Tutoring in a Non-Profit' at time            12h35
#
# ⏰Simple Scheduler at time 12h35            started executing task 8 that takes 180 mins
# ✅ Completed Task 8 - 'Study and do work (at SF Library)' at time            15h35
#
# ⏰Simple Scheduler at time 15h35            started executing task 15 that takes 2 mins
# ⏰Simple Scheduler at time 15h35            started executing task 16 that takes 5 mins
# ✅ Completed Task 15 - 'Text my Yoga buddy to arrange going for Yoga' at time            15h37
#
# ✅ Completed Task 16 - 'Clean the Yoga mat' at time            15h40
#
# ⏰Simple Scheduler at time 15h40            started executing task 3 that takes 60 mins
# ✅ Completed Task 3 - 'Doing Yoga' at time            16h40
#
# ⏰Simple Scheduler at time 16h40            started executing task 9 that takes 60 mins
# ✅ Completed Task 9 - 'Call Family' at time            17h40
#
# ⏰Simple Scheduler at time 17h40            started executing task 6 that takes 120 mins
# ✅ Completed Task 6 - 'Make healthy food' at time            19h40
#
# ⏰Simple Scheduler at time 19h40            started executing task 19 that takes 20 mins
# ✅ Completed Task 19 - 'Take a fitness lesson by my trainer' at time            20h00
#
# ⏰Simple Scheduler at time 20h00            started executing task 5 that takes 45 mins
# ✅ Completed Task 5 - 'Working out in the Gym' at time            20h45
#
# ⏰Simple Scheduler at time 20h45            started executing task 18 that takes 5 mins
# ⏰Simple Scheduler at time 20h45            started executing task 17 that takes 5 mins
# ✅ Completed Task 18 - 'Search on Maps for new places to visit' at time            20h50
#
# ✅ Completed Task 17 - 'Text my friends to arrange going out' at time            20h50
#
# ⏰Simple Scheduler at time 20h50            started executing task 4 that takes 60 mins
# ✅ Completed Task 4 - 'Going out with friends' at time            21h50
#
# ⏰Simple Scheduler at time 21h50            started executing task 12 that takes 5 mins
# ✅ Completed Task 12 - 'Tune the violin strings' at time            21h55
#
# ⏰Simple Scheduler at time 21h55            started executing task 11 that takes 10 mins
# ⏰Simple Scheduler at time 21h55            started executing task 10 that takes 30 mins
# ✅ Completed Task 11 - 'Studying music theory' at time            22h05
#
# ✅ Completed Task 10 - 'Listen to my Friend's recent musical piece' at time            22h25
#
# ⏰Simple Scheduler at time 22h25            started executing task 2 that takes 30 mins
# ✅ Completed Task 2 - 'Playing Violin' at time            22h55
#
# 🏁 Completed all planned tasks in 14h55min

# %% [raw]
# A.
#
# It was very helpful to follow the instructions in the assignment description. For me they provided cues that inspired ideas and drew my attention to what eventually helped me solve the problem. The fact that it mentions what exactly is expected of our outcome to be and what constraints could be there gets us steps closer to the solution by, for example, telling me that I should keep track of the remaining time of each task when multitasking (obstacle) in order to accurately report the beginning and end time of each (expectation). Instructions were also useful to propose some ideas for priority values.
#
#
# My scheduler could face problems because of the narrow range of my priority value. I might improve on it by either using a different metric or by, more preferably, using the same metric scaled to larger numbers so that there exist substantial differences between priority values of my different tasks (e.g. gym and calling family).
#
#
#
#
#
# B.
#
#   My schedule is efficent because it first considers what really matters, executes all what it needs to finish it (and multitasks what could be done together for time efficiency), records the time for each step, and then goes to the one that matters next, and so on. "What matters" here is determined by the urgency of the task, or what would happen if I didn't do it today (Can it be done tomorrow?). I also start with tasks that need my attention more (service, tutoring, and studying), then do yoga to refresh, call family for a better mood, and then look after my health in terms of diet and exercise. After that, I will be mentally tired, so it will be a good idea to just hangout with friends, which is also essential for mental health, and can be done any day except Thursday (I have Capstone and workstudy) and Monday (the busy beginning of the week). Finally, I like to end my day with some music to have good dreams, but I can't do that on Friday because I have workstudy the whole evening.
#
#   I could improve my schedule by making it flexible and robust to shortcomings. If, for example, an emergency occured I don't want my schedule to be useless; instead, I want it to re-manage tasks that can still happen after the emergency event finishes. I can theoritically implement this in Python, but I still cannot predict or account for any emergencies that might occur or how long they will last.
#
#
# C.
#
# I can use this schedule to plan my day given the constraints of on what day each task could or could not be done. I can expand upon it by making a schedule for each weekday, which will include, for example, other tasks than "Church Service" which happends only on Sundays, such as Mass on Saturdays. To use this schedule, I need to train myself to be more productive and waste less time each day so that I can follow all tasks, or make the schedule more tolerant of my shortcomings. Some tasks could also be done twice, such as Calling family. Assuming that I trained myself on productivity, I don't have to do any task more than twice (or have discipline to not do so), and I have day-specific tasks for each day, I can started using this schedule effectively.

# %% [raw]
# HCs:
#
# #constraints: I mentioned that for a very flexible task like scheduling my day, using a computational program could be useful but I could also run into obstacles and constraints along the way. In my scheduler, the fact that not all tasks that can be multitasked can be done with each other imposed an obstacle that I overcame by using the 0-1 values and by restricting the search to related tasks in the priority queue. On the other hand, the fact that I must use one priority metric for all task types imposes a constraint that I partially overcame by choosing a plausible priority value for each main task, but these priority values better be scaled in order to make them distinct between tasks that I want to sort them in a specific way. Finally, I faced a submission constraints when I needed to shorten my lines to be included in the PDF, which has caused some of my outputs to just look differently.
#
# #selfawareness: When I reflected on the efficiency of my schedule, I was aware of my personal limitations when it comes to productivity and time wasted. This awareness guided my goal from the scheduler and helped me determine some current along with future directions to improve my schedule.
#
# #algorithms: I explained and implemented an algorithm for each of the two questions, justified most of me choices in the algorithm, and included my expected outputs. I also explained my code, that was partially guided by preclass work, and reflected on its efficiency in different parts, along with the efficiency of my algorithmic strategies.
